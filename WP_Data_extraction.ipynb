# %%
# importing standard modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import PyPDF2
import pdfkit

# %%
df = pd.read_csv('data/data_project.csv')

# %%
df.head()
# Out:
#    FID  Serial      Lat     Long  GWL18   Aspect  Curvature  Drainage_density  \
# 0    0       1  25.1324  90.4851  24.53   90.000   0.216315          0.062237
# 1    1       2  25.1329  90.4011  25.60    0.000  -0.108158          0.067682
# 2    2       3  25.1221  90.4479  25.15  153.435  -0.216315          0.071419
# 3    3       4  25.1212  90.4221  25.62   71.565   0.108158          0.071250
# 4    4       5  25.1055  90.3242  27.00  150.255  -0.973418          0.082019
#
#    Elevation  GWL_m  ...  GWL_m_SP1  GWL_f_SP1  Distance_from_stream  \
# 0         19  7.359  ...   3.168455   1.886685               8056.66
# 1         16  7.680  ...   9.555959   2.395600               5790.00
# 2         15  7.545  ...   4.238886   4.667708               5791.17
# 3         17  7.686  ...   3.602039   3.313003               4679.33
# 4         15  8.100  ...   5.906491  18.868374               2661.90
#
#    Lithology  Plan_curvature  Profile_curvature  Slope_degree       TWI1  \
# ...
